# %% [markdown]
# # Projet _Analyse de données :

# %% [markdown]
# Dans ce projet, nous allons effectuer un scrapping sur Google Scholar afin d'extraire des données relatives à une recherche, puis les regrouper dans un tableau exhaustif dans un fichier Excel. Ensuite, nous analyserons ces données en utilisant des outils que nous avons étudiés tels que la régression, l'ACP, l'ANOVA, en commençant par subdiviser le grand tableau en petits tableaux en fonction des colonnes nécessaires.

# %% [markdown]
# Nous avons commencé par extraire le plus grand nombre possible de données que nous pouvons recueillir, puis les avons intégrées dans le fichier chercheur.xlsx :

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\chercheur.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#                                       Auteur  \
# 0                               Zhi-Hua Zhou
# 1                             Jacob Biamonte
# 2                               Peter Wittek
# 3                            Nicola Pancotti
# 4                         Patrick Rebentrost
# 5                                     Mahesh
# 6                               Tom Mitchell
# 7                             Pramila Shinde
# 8                                 Seema Shah
# 9   Issam El Naqa, PhD, FAAPM, FIEEE, FAIMBE
# 10                       Giuseppe Bonaccorso
# 11                            Foster Provost
# 12                                Ron Kohavi
# 13                        Christian Janiesch
# 14                           Patrick Zschech
# 15                              Kai Heinrich
# 16                      Zhiyuan (Brett) Chen
# 17                                  Bing Liu
#
#                                            Universite  Citations totales  \
# ...

# %% [markdown]
# Pour la régression, nous avons choisi de travailler dans un premier temps avec les variables "Citations totales" et "Indice h total", puis avec les variables "Indice h total" et "i-index Toutes" dans un deuxième temps.

# %% [markdown]
# # Regression :

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\regression1.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#     Citations totales  Indice h total
# 0               88789             123
# 1                8755              39
# 2                5925              25
# 3                3898               9
# 4               13079              28
# 5               20999              10
# 6               77287              98
# 7                 553               2
# 8                 846              10
# 9               26529              70
# 10                981               7
# 11              32324              67
# 12              60981              63
# 13               4335              30
# 14               1728              15
# 15               1599              14
# 16               2882              16
# 17              96322             111

# %%
Indice h total et i-index Toutes

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\reg.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#     Indice h total  i-index Toutes
# 0              123             442
# 1               39              66
# 2               25              46
# 3                9               9
# 4               28              39
# 5               10              10
# 6               98             285
# 7                2               2
# 8               10              10
# 9               70             219
# 10               7               7
# 11              68             145
# 12              62              88
# 13              30              72
# 14              16              26
# 15              14              21
# 16              16              19
# 17             111             309

# %% [markdown]
# # Anova

# %% [markdown]
# Pour ANOVA , nous avons choisi de travailler dans un premier temps avec les variables "Citations totales" et "fields".

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\anova1.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#     Citations totales                                             fields
# 0               88789  Artificial IntelligenceMachine LearningData Mi...
# 1                8755  quantum algorithmsmachine learningquantum engi...
# 2                3898   Quantum DynamicsTensor NetworksQuantum Computing
# 3               20999                Research on Chemical and Automotive
# 4               77287  Machine Learningcognitive neurosciencenatural ...
# 5                 553     Artificial IntelligenceWeb TechnologyAnalytics
# 6                 846  BlockchainDistributed ComputingCloud Computing...
# 7               26529  Machine LearningArtificial IntelligenceMedical...
# 8                 981        AIMachine LearningDeep LearningData Science
# 9               32324  machine learninginformation systemsdata mining...
# 10              60981  Controlled ExperimentsA/B testingMachine Learn...
# 11               4335  Enterprise ComputingBusiness InformaticsBusine...
# ...

# %% [markdown]
# # AFC

# %% [markdown]
# Pour AFC nous avons choisi de travailler dans un premier temps avec les variables "Universite" et "fields".

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\affcc.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#                                            Universite  \
# 0                                  Nanjing University
# 1                     NASA Ames Research Center, USRA
# 2   Quantum Research Scientist at AWS & California...
# 3                                Affiliation inconnue
# 4   Assistant Professor, IT, Shah & Anchor Kutchhi...
# 5   Director,Head, Computer Engineering Department...
# 6   Founders University Professor of Machine Learn...
# 7   Chair of Machine Learning, H. Lee Moffitt Canc...
# 8                   Global Head of Data Science - ACM
# 9                      Professor, New York University
# 10  Technical Fellow and Vice President, Analysis ...
# 11                             TU Dortmund University
# 12                                 Leipzig University
# 13            Otto-von-Guericke Universität Magdeburg
# 14          University of Illinois at Chicago, Google
# 15  Distinguished Professor, University of Illinoi...
#
# ...

# %% [markdown]
# # ACP

# %% [markdown]
# Pour ACP, nous avons choisi de travailler dans un premier temps avec les variables "Citations totales" et "Indice h total" et "i-index Toutes", puis avec les variables "Total des citations Depuis 2018" et "Indice h Depuis 2018" et	"i-index Depuis 2018" , ensuite acec les variables "Citations totales" 	"Total des citations Depuis 2018" 	"Indice h total" 	"Indice h Depuis 2018" 	"i-index Toutes" 	"i-index Depuis 2018".

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\acp1.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#     Citations totales  Indice h total  i-index Toutes
# 0               89025             123             442
# 1                8824              39              66
# 2                5960              25              46
# 3                3924               9               9
# 4               13147              28              39
# 5               21057              10              10
# 6               77517              98             285
# 7                 560               2               2
# 8                 854              10              10
# 9               26590              70             219
# 10                985               7               7
# 11              32416              68             145
# 12              61063              62              88
# 13               4391              30              72
# 14               1755              16              26
# 15               1619              14              21
# ...

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\acp3.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#     Total des citations Depuis 2018  Indice h Depuis 2018  i-index Depuis 2018
# 0                             54870                    91                  373
# 1                              7321                    36                   55
# 2                              5407                    24                   32
# 3                              3835                     9                    9
# 4                              9596                    28                   37
# 5                             13663                    10                   10
# 6                             31293                    62                  173
# 7                               557                     2                    2
# 8                               748                     8                    7
# 9                             16576                    53                  186
# 10                              970                     7                    7
# ...

# %%
import pandas as pd

# Spécifiez le chemin du fichier Excel
chemin_du_fichier_excel = r"C:\Users\msi\Desktop\S1\Analyse de BD\GoogleShcolar\acp2.xlsx"

# Chargez le fichier Excel dans un DataFrame pandas
dataframe_excel = pd.read_excel(chemin_du_fichier_excel)

# Affichez les premières lignes du DataFrame pour vérification
dataframe_excel
# Out:
#     Citations totales  Total des citations Depuis 2018  Indice h total  \
# 0               89025                            54870             123
# 1                8824                             7321              39
# 2                5960                             5407              25
# 3                3924                             3835               9
# 4               13147                             9596              28
# 5               21057                            13663              10
# 6               77517                            31293              98
# 7                 560                              557               2
# 8                 854                              748              10
# 9               26590                            16576              70
# 10                985                              970               7
# 11              32416                            12585              68
# ...
